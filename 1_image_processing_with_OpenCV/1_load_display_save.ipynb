# %%
import numpy as np
import cv2 # opencv library

# %%
img = cv2.imread('./images/car_001.jpeg')
cv2.startWindowThread()
# Out:
# 0

# %% [markdown]
# # Display

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img[:,:,[2,1,0]]) # assumes image is in rgb format
plt.show()

# %% [markdown]
# ## Save Image

# %%
cv2.imwrite('./images/save.png',img)
# Out:
# True

# %%
img.shape
# Out:
# (423, 612, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
def display(img):
    plt.imshow(img[:,:,[2,1,0]]) # assumes image is in rgb format
    plt.show()

# %%
# access first 300 rows (height) and first 300 columns (width) of image
roi = img[0:300,0:300]
display(roi)

# %% [markdown]
# ## Manipulate Pixels

# %%
display(img)

# %%
b,g,r = cv2.split(img)

# %%
print(b)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
b.shape,g.shape,r.shape
# Out:
# ((423, 612), (423, 612), (423, 612))
